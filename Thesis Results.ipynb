# %% [raw]
# results q0.25 q1.28

# %% [raw]
# complete DIAWUG
# micro,precision,0.2567049808429119
# micro,recall,0.2567049808429119
# micro,fscore,0.2567049808429119
# macro,precision,0.087995337995338
# macro,recall,0.10696034836859644
# macro,fscore,0.08465081950154259
# ,support,522.0

# %% [raw]
# banco
# micro,precision,0.7142857142857143
# micro,recall,0.7142857142857143
# micro,fscore,0.7142857142857143
# macro,precision,0.17857142857142858
# macro,recall,0.25
# macro,fscore,0.20833333333333331
# ,support,28.0

# %% [raw]
# bolo
# micro,precision,0.0
# micro,recall,0.0
# micro,fscore,0.0
# macro,precision,0.0
# macro,recall,0.0
# macro,fscore,0.0
# ,support,23.0

# %% [raw]
# cartera/bolso
# micro,precision,0.0
# micro,recall,0.0
# micro,fscore,0.0
# macro,precision,0.0
# macro,recall,0.0
# macro,fscore,0.0
# ,support,42.0

# %% [raw]
# chamaco/pibe/chico
# micro,precision,0.0
# micro,recall,0.0
# micro,fscore,0.0
# macro,precision,0.0
# macro,recall,0.0
# macro,fscore,0.0
# ,support,42.0

# %% [raw]
# churro
# micro,precision,0.0
# micro,recall,0.0
# micro,fscore,0.0
# macro,precision,0.0
# macro,recall,0.0
# macro,fscore,0.0
# ,support,25.0

# %% [raw]
# coche/carro
# micro,precision,0.9333333333333333
# micro,recall,0.9333333333333333
# micro,fscore,0.9333333333333333
# macro,precision,0.4666666666666667
# macro,recall,0.5
# macro,fscore,0.4827586206896552
# ,support,30.0

# %% [raw]
# flete
# micro,precision,1.0
# micro,recall,1.0
# micro,fscore,1.0
# macro,precision,1.0
# macro,recall,1.0
# macro,fscore,1.0
# ,support,30.0

# %% [raw]
# gato
# micro,precision,0.9
# micro,recall,0.9
# micro,fscore,0.9
# macro,precision,0.3
# macro,recall,0.3333333333333333
# macro,fscore,0.31578947368421056
# ,support,30.0

# %% [raw]
# guagua/colectivo
# micro,precision,0.041666666666666664
# micro,recall,0.041666666666666664
# micro,fscore,0.041666666666666664
# macro,precision,0.13095238095238096
# macro,recall,0.01688664596273292
# macro,fscore,0.029914529914529912
# ,support,72.0

# %% [raw]
# plomero/fontanero
# micro,precision,0.0
# micro,recall,0.0
# micro,fscore,0.0
# macro,precision,0.0
# macro,recall,0.0
# macro,fscore,0.0
# ,support,42.0

# %% [raw]
# pollera/falda
# micro,precision,0.0
# micro,recall,0.0
# micro,fscore,0.0
# macro,precision,0.0
# macro,recall,0.0
# macro,fscore,0.0
# ,support,30.0

# %% [raw]
# saco
# micro,precision,0.0
# micro,recall,0.0
# micro,fscore,0.0
# macro,precision,0.0
# macro,recall,0.0
# macro,fscore,0.0
# ,support,26.0

# %% [raw]
# tinto
# micro,precision,0.5333333333333333
# micro,recall,0.5333333333333333
# micro,fscore,0.5333333333333333
# macro,precision,0.20512820512820515
# macro,recall,0.3137254901960784
# macro,fscore,0.248062015503876
# ,support,30.0

# %% [raw]
# vaina
# micro,precision,0.03571428571428571
# micro,recall,0.03571428571428571
# micro,fscore,0.03571428571428571
# macro,precision,0.007142857142857143
# macro,recall,0.2
# macro,fscore,0.013793103448275858
# ,support,28.0

# %% [raw]
# vereda
# micro,precision,0.0
# micro,recall,0.0
# micro,fscore,0.0
# macro,precision,0.0
# macro,recall,0.0
# macro,fscore,0.0
# ,support,30.0

# %% [raw]
# volante/timón
# micro,precision,0.6428571428571429
# micro,recall,0.6428571428571429
# micro,fscore,0.6428571428571429
# macro,precision,0.0989010989010989
# macro,recall,0.14285714285714285
# macro,fscore,0.11688311688311688
# ,support,14.0

# %% [raw]
# results q1 q1 mewsli large spanish dataset
# micro,precision,0.8102344218094667
# micro,recall,0.8102344218094667
# micro,fscore,0.8102344218094668
# macro,precision,0.6842544853596937
# macro,recall,0.6729932414126748
# macro,fscore,0.6725895445362952
# ,support,53408.0
#
# results small spanish dataset
# micro,precision,0.8164400494437577
# micro,recall,0.8164400494437577
# micro,fscore,0.8164400494437577
# macro,precision,0.7278309409888358
# macro,recall,0.7248327228327227
# macro,fscore,0.7255719864182788
# ,support,1618.0

# %% [raw]
# results q0.25 q0.25 mewsli large spanish dataset
# micro,precision,0.7721689634511684
# micro,recall,0.7721689634511684
# micro,fscore,0.7721689634511685
# macro,precision,0.6450139979447505
# macro,recall,0.6306691140549505
# macro,fscore,0.6316074591188826
# ,support,53408.0
#
# results small spanish dataset
# micro,precision,0.7707045735475896
# micro,recall,0.7707045735475896
# micro,fscore,0.7707045735475896
# macro,precision,0.6792118774624023
# macro,recall,0.6762574432798366
# macro,fscore,0.6766108170656806
# ,support,1618.0

# %%
# results data trained on q0.25
import matplotlib.pyplot as plt

def plot_results(x_data,y_data):
    plt.bar(x_data,y_data)
    plt.ylabel("micro f1-score")
    plt.title("q0.25 individual f1-score results")
    plt.xticks(rotation=45)
    plt.axhline(y=0.7707045735475896, color="r", linestyle="--",linewidth=1)
    plt.tight_layout()
    plt.show()
    
x_data = ["Complete","Mewsli-sm","banco","bolo","cartera","chamaco","churro" ,"coche" ,"flete" ,"gato" ,
          "guagua" ,"plomero","pollera","saco","tinto",
          "vaina","vereda","volante"
]
y_data = [0.2567049808429119,0.7707045735475896,0.7142857142857143,0.0,0.0,0.0,0.0,0.9333333333333333,1.0,0.9,0.041666666666666664,
          0.0,0.0,0.0,0.5333333333333333,0.03571428571428571,0.0,0.6428571428571429]

plot_results(x_data,y_data)

# %%
# results data trained on all data

def plot_results(x_data,y_data):
    plt.bar(x_data,y_data)
    plt.ylabel("micro f1-score")
    plt.title("q1 individual f1-score results")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.axhline(y=0.8164400494437577, color="r", linestyle="--",linewidth=1)
    plt.show()
    
x_data = ["Complete","Mewsli-sm","banco","bolo","cartera","chamaco","churro" ,"coche" ,"flete" ,"gato" ,
          "guagua" ,"plomero","pollera","saco","tinto",
          "vaina","vereda","volante"
]
y_data = [0.3544061302681992,0.8164400494437577,0.7142857142857143,0.043478260869565216,0.023809523809523808,0.0,0.72,
          0.9333333333333333,1.0,0.9,0.041666666666666664,0.35714285714285715,0.4666666666666667,
          0.07692307692307693,0.5333333333333333,0.03571428571428571,0.0,0.6428571428571429]

plot_results(x_data,y_data)
